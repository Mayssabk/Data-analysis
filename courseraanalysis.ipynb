# %%
import pandas as pd
coursera_df=pd.read_csv(r"C:\Users\HP\Downloads\archive (1)\udemy_courses_dataset.csv")
type(coursera_df)
# Out:
# pandas.core.frame.DataFrame

# %%
coursera_df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
coursera_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
coursera_df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
coursera_df.shape
# Out:
# (3678, 12)

# %%
prices_df=coursera_df[['course_title','price']]
prices_df
# Out:
#                                            course_title  price
# 0                    Ultimate Investment Banking Course    200
# 1     Complete GST Course & Certification - Grow You...     75
# 2     Financial Modeling for Business Analysts and C...     45
# 3     Beginner to Pro - Financial Analysis in Excel ...     95
# 4          How To Maximize Your Profits Trading Options    200
# ...                                                 ...    ...
# 3673  Learn jQuery from Scratch - Master of JavaScri...    100
# 3674  How To Design A WordPress Website With No Codi...     25
# 3675                      Learn and Build using Polymer     40
# 3676  CSS Animations: Create Amazing Effects on Your...     50
# 3677  Using MODX CMS to Build Websites: A Beginner's...     45
#
# [3678 rows x 2 columns]

# %%
num_of_subscribers_df=coursera_df[['course_title','num_subscribers']]
num_of_subscribers_df
# Out:
#                                            course_title  num_subscribers
# 0                    Ultimate Investment Banking Course             2147
# 1     Complete GST Course & Certification - Grow You...             2792
# 2     Financial Modeling for Business Analysts and C...             2174
# 3     Beginner to Pro - Financial Analysis in Excel ...             2451
# 4          How To Maximize Your Profits Trading Options             1276
# ...                                                 ...              ...
# 3673  Learn jQuery from Scratch - Master of JavaScri...             1040
# 3674  How To Design A WordPress Website With No Codi...              306
# 3675                      Learn and Build using Polymer              513
# 3676  CSS Animations: Create Amazing Effects on Your...              300
# 3677  Using MODX CMS to Build Websites: A Beginner's...              901
#
# [3678 rows x 2 columns]

# %%
levels_df=coursera_df[['course_title','level']]
levels_df
# Out:
#                                            course_title               level
# 0                    Ultimate Investment Banking Course          All Levels
# 1     Complete GST Course & Certification - Grow You...          All Levels
# 2     Financial Modeling for Business Analysts and C...  Intermediate Level
# 3     Beginner to Pro - Financial Analysis in Excel ...          All Levels
# 4          How To Maximize Your Profits Trading Options  Intermediate Level
# ...                                                 ...                 ...
# 3673  Learn jQuery from Scratch - Master of JavaScri...          All Levels
# 3674  How To Design A WordPress Website With No Codi...      Beginner Level
# 3675                      Learn and Build using Polymer          All Levels
# 3676  CSS Animations: Create Amazing Effects on Your...          All Levels
# 3677  Using MODX CMS to Build Websites: A Beginner's...      Beginner Level
#
# [3678 rows x 2 columns]

# %%
total_num_of_subscribers = num_of_subscribers_df.num_subscribers.sum()
total_num_of_reviews = coursera_df.num_reviews.sum()

print("The total number of subscribers is {} and the total number of reviews is {}".format(int(total_num_of_subscribers), int(total_num_of_reviews)))
# Out:
# The total number of subscribers is 11759120 and the total number of reviews is 574721

# %%
#the overall rate of reviews
review_rate=total_num_of_reviews/total_num_of_subscribers
print("the overall ratio of reviews is {:.2f} %".format(review_rate*100))
# Out:
# the overall ratio of reviews is 4.89 %

# %%
#calculate the percentage of paid courses 
paid_percentage=coursera_df['is_paid'].value_counts(normalize=True)*100
print("the percentage of paid courses: {:.2f} %".format(paid_percentage[True]))
print("the percentage of free courses: {:.2f} %".format(paid_percentage[False]))
# Out:
# the percentage of paid courses: 91.57 %
# the percentage of free courses: 8.43 %

# %%
#the average of content duration
average_content_duration=coursera_df['content_duration'].mean()
print("the average of content duration is: {}".format(average_content_duration))
# Out:
# the average of content duration is: 4.094516947616459

# %%
# Calculate the percentage of each level
course_level = coursera_df['level'].value_counts(normalize=True) * 100

print("The percentage of Beginner Level courses: {:.2f}%".format(course_level['Beginner Level']))
print("The percentage of Intermediate Level courses: {:.2f}%".format(course_level['Intermediate Level']))
print("The percentage of All Levels courses: {:.2f}%".format(course_level['All Levels']))
print("The percentage of Expert Level courses: {:.2f}%".format(course_level['Expert Level']))
# Out:
# The percentage of Beginner Level courses: 34.53%
# The percentage of Intermediate Level courses: 11.45%
# The percentage of All Levels courses: 52.45%
# The percentage of Expert Level courses: 1.58%

# %%
# Calculate the percentage of each subject
subject_percentage = coursera_df['subject'].value_counts(normalize=True) * 100
subject_percentage_formatted = subject_percentage.apply(lambda x: f"{x:.2f}%")
print(subject_percentage_formatted)
# Out:
# subject
# Web Development        32.63%
# Business Finance       32.49%
# Musical Instruments    18.49%
# Graphic Design         16.39%
# Name: proportion, dtype: object

# %%
#showing only the courses that their prices are higher than 150
high_prices_df=coursera_df[coursera_df.price>150]
high_prices_df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 4       1011058       How To Maximize Your Profits Trading Options
# 8        476268  Options Trading 3 : Advanced Stock Profit and ...
# 9       1167710  The Only Investment Strategy You Need For Your...
# 10       592338  Forex Trading Secrets of the Pros With Amazon'...
# ...         ...                                                ...
# 3620    1227578           Learning Path: The Road to Elasticsearch
# 3642     709324  Learn Web Development by Creating a Social Net...
# 3647     975916  17 Complete JavaScript   projects explained st...
# 3652     919354  Learn Bootstrap 4 The Most Popular HTML5 CSS3 ...
# 3654     949134  The Extreme Web Development Course - For Begin...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
#sorting the 10 high_priced courses
high_prices_df.sort_values('price', ascending=False).head(10)
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 2022     517148  Acoustic Fingerstyle Guitar Course: Beginner t...
# 2500     924704  Ultimate Web Developer Course Build 10 Website...
# 2490    1146014                     Learn JavaScript for beginners
# 2486     965528  Web Development Masterclass - Complete Certifi...
# 2463     441996  Bones of the Blues - learn 4 cool tunes to exp...
# 2435      22825                             Beginner Guitar Method
# 2207    1261210                                Suonare la Chitarra
# 2045     917432                  The Professional Bass Masterclass
# 2023     206088  Guitar Chord Mastery!Turn Your Brain Into A Ch...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# 2022  https://www.udemy.com/acoustic-fingerstyle-gui...     True    200
# ...

# %%
#courses with the highest number of lectures 
max_lectures = coursera_df['num_lectures'].max()
courses_with_max_lectures = coursera_df[coursera_df['num_lectures'] == max_lectures]
print(courses_with_max_lectures)
# Out:
#       course_id                                       course_title  \
# 2707      79154  Back to School Web Development and Programming...
#
#                                                     url  is_paid  price  \
# 2707  https://www.udemy.com/back-to-school-web-devel...     True    200
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 2707            18170          117           779  Beginner Level
#
#       content_duration   published_timestamp          subject
# 2707              44.5  2013-08-19T14:53:00Z  Web Development

# %%
# !pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
coursera_df=pd.read_csv(r"C:\Users\HP\Downloads\archive (1)\udemy_courses_dataset.csv")
sns.set(style="whitegrid")
#Histogram for number of subscribers
plt.figure(figsize=(10, 6))
plt.hist(coursera_df['num_subscribers'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Number of Subscribers')
plt.xlabel('Number of Subscribers')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar Chart for count of courses per subject
plt.figure(figsize=(10, 6))
coursera_df['subject'].value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Number of Courses per Subject')
plt.xlabel('Subject')
plt.ylabel('Number of Courses')
plt.show()

# %%
# Scatter Plot for number of reviews vs. number of subscribers
plt.figure(figsize=(10, 6))
plt.scatter(coursera_df['num_reviews'], coursera_df['num_subscribers'], alpha=0.5, color='coral')
plt.title('Number of Reviews vs. Number of Subscribers')
plt.xlabel('Number of Reviews')
plt.ylabel('Number of Subscribers')
plt.show()

# %%
# Heat Map of correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(coursera_df[['price', 'num_subscribers', 'num_reviews', 'num_lectures', 'content_duration']].corr(), 
            annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
